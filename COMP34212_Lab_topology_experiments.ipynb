# %% [markdown]
# <a href="https://colab.research.google.com/github/TomShimo0/COMP34212-Lab/blob/main/COMP34212_Lab_topology_experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Advanced Convolutional Neural Networks (CNNs) with CIFAR-10 dataset
# =========
#
# In this tutorial we will learn how to use more complex CNNs, showing that the training of a __deeper__ CNN can improve the performance of the model. We will also explore the concept of __data augmentation__ to understand how to increase the variability of the training set by, for example, rotating the original images to generate new training stimuli.
#
# This tutorail will use the CIFAR-10 training set.

# %% [markdown]
# **CNN for CIFAR-10**
#
# To work with more complex CNNs, we will now use a more complex training dataset called __CIFAR-10__. https://www.cs.toronto.edu/~kriz/cifar.html . CIFAR-10 is a benchamark machine learning set of low-resolution, colour images. It includes 60000 32x32 colour (using 3 RGB colour channels) images in these 10 classes of objects: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck. Each class has 6000. There are 50000 training images and 10000 test images. This dataset is enclosed in the default Anaconda KERAS package.

# %% [markdown]
# **Initialisation of the program**
#
# The program starts with the importing of typical Keras and other Python service modules.

# %%
# importing of modules for CIFAR-10 CNN
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import utils
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers.legacy import SGD, Adam, RMSprop

# importing of service libraries
import numpy as np
import matplotlib.pyplot as plt

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# The following constant and variable definitions are needed for the network and training parameters.

# %%
#training constants
BATCH_SIZE = 128
N_EPOCH = 40
N_CLASSES = 10
VERBOSE = 1
VALIDATION_SPLIT = 0.2
OPTIM = Adam()

print('Main variables initialised.')
# Out:
# Main variables initialised.

# %% [markdown]
# Constant definition for the training set images

# %%
# CIFAR_10 is a set of 60K images 32x32 pixels on 3 channels
IMG_CHANNELS = 3
IMG_ROWS = 32
IMG_COLS = 32

print('Image variables initialisation')
# Out:
# Image variables initialisation

# %% [markdown]
# __CIFAR-10 data loading and processing__
#
# Loading and preparation of the CIFAR-10 training set.

# %%
#load dataset
(input_X_train, output_y_train), (input_X_test, output_y_test) = cifar10.load_data()
print('input_X_train shape:', input_X_train.shape)
print(input_X_train.shape[0], 'train samples')
print(input_X_test.shape[0], 'test samples')

# convert to categorical
output_Y_train = utils.to_categorical(output_y_train, N_CLASSES)
output_Y_test = utils.to_categorical(output_y_test, N_CLASSES)

# float and normalization
input_X_train = input_X_train.astype('float32')
input_X_test = input_X_test.astype('float32')
input_X_train /= 255
input_X_test /= 255
# Out:
# input_X_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# Topology experiments
# -------------
#
# The original network provided was of the structure:
#
# conv+conv+maxpool+dropout+conv+conv+maxpool+droupout+[classification]
#
# I would like to compare this to the performance of:
#
# conv+conv+maxpool+dropout+[classification]    (only one layer)
#
# and
#
# conv+conv+maxpool+dropout+conv+conv+maxpool+dropout+conv+conv+maxpool+dropout+[classification]     (one more layer)
#
#
# [classification] is the standard classification layer:
# dense+dropout+dense
#
# All the layers will use the reLu function, except the final one with the Softmax function necessary for the categorical classification

# %%
# Complex DNN model definition (standard)
modelS = Sequential()

modelS.add(Conv2D(32, kernel_size=3, padding='same', input_shape=(IMG_ROWS, IMG_COLS, IMG_CHANNELS)))
modelS.add(Activation('relu'))
modelS.add(Conv2D(32, kernel_size=3, padding='same'))
modelS.add(Activation('relu'))
modelS.add(MaxPooling2D(pool_size=(2, 2)))
modelS.add(Dropout(0.25))

modelS.add(Conv2D(64, kernel_size=3, padding='same'))
modelS.add(Activation('relu'))
modelS.add(Conv2D(64, 3, 3))
modelS.add(Activation('relu'))
modelS.add(MaxPooling2D(pool_size=(2, 2)))
modelS.add(Dropout(0.25))

modelS.add(Flatten())
modelS.add(Dense(512))
modelS.add(Activation('relu'))
modelS.add(Dropout(0.5))
modelS.add(Dense(N_CLASSES))
modelS.add(Activation('softmax'))


#optim = Adam() default values
modelS.compile(loss='categorical_crossentropy', optimizer=OPTIM, metrics=['accuracy'])

#model.summary()

# %%
# Complex DNN model definition (1 less layers)
modelL = Sequential()

modelL.add(Conv2D(64, kernel_size=3, padding='same', input_shape=(IMG_ROWS, IMG_COLS, IMG_CHANNELS)))
modelL.add(Activation('relu'))
modelL.add(Conv2D(64, kernel_size=3, padding='same'))
modelL.add(Activation('relu'))
modelL.add(MaxPooling2D(pool_size=(2, 2)))
modelL.add(Dropout(0.25))

modelL.add(Flatten())
modelL.add(Dense(512))
modelL.add(Activation('relu'))
modelL.add(Dropout(0.5))
modelL.add(Dense(N_CLASSES))
modelL.add(Activation('softmax'))


#optim = Adam() default values
modelL.compile(loss='categorical_crossentropy', optimizer=OPTIM, metrics=['accuracy'])

#modelL.summary()

# %%
# Complex DNN model definition (1 more layers)
modelM = Sequential()

modelM.add(Conv2D(32, kernel_size=(3, 3), padding='same', input_shape=(IMG_ROWS, IMG_COLS, IMG_CHANNELS)))
modelM.add(Activation('relu'))
modelM.add(Conv2D(32, kernel_size=(3, 3), padding='same'))
modelM.add(Activation('relu'))
modelM.add(MaxPooling2D(pool_size=(2, 2)))
modelM.add(Dropout(0.25))

modelM.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
modelM.add(Activation('relu'))
modelM.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
modelM.add(Activation('relu'))
modelM.add(MaxPooling2D(pool_size=(2, 2)))
modelM.add(Dropout(0.25))

modelM.add(Conv2D(128, kernel_size=(3, 3), padding='same'))
modelM.add(Activation('relu'))
modelM.add(Conv2D(128, kernel_size=(3, 3), padding='same'))
modelM.add(Activation('relu'))
modelM.add(MaxPooling2D(pool_size=(2, 2)))
modelM.add(Dropout(0.25))

modelM.add(Flatten())
modelM.add(Dense(512))
modelM.add(Activation('relu'))
modelM.add(Dropout(0.5))
modelM.add(Dense(N_CLASSES))
modelM.add(Activation('softmax'))

modelM.compile(loss='categorical_crossentropy', optimizer=OPTIM, metrics=['accuracy'])

#model.summary()

# %% [markdown]
# **Training of the deeper CNNs**
#
# Let's train (fit) these models.

# %%
# make a list of models
models = [modelS, modelL, modelM]
histories = []
scores = []
model_names = ['base', 'less', 'more']
score_colours = ['r', 'g', 'b']

# %%
# training/fitting of the complex DNN models, recording data in lists
for model in models:
  history = model.fit(input_X_train, output_Y_train, batch_size=BATCH_SIZE, epochs=N_EPOCH, validation_split=VALIDATION_SPLIT,  verbose=VERBOSE)
  histories.append(history)

  # evaluation on test set
  score = model.evaluate(input_X_test, output_Y_test, batch_size=BATCH_SIZE, verbose=VERBOSE)
  scores.append(score)
  print("\nTest score/loss:", score[0])
  print('Test accuracy:', score[1])
# Out:
# Epoch 1/40
# 313/313 [==============================] - 11s 16ms/step - loss: 1.8982 - accuracy: 0.2860 - val_loss: 1.6419 - val_accuracy: 0.3832
# Epoch 2/40
# 313/313 [==============================] - 4s 12ms/step - loss: 1.5710 - accuracy: 0.4155 - val_loss: 1.3980 - val_accuracy: 0.4873
# Epoch 3/40
40
# 313/313 [==============================] - 6s 18ms/step - loss: 1.1154 - accuracy: 0.6039 - val_loss: 1.1465 - val_accuracy: 0.5945
# Epoch 12/40
# 313/313 [==============================] - 6s 19ms/step - loss: 1.0880 - accuracy: 0.6160 - val_loss: 1.1511 - val_accuracy: 0.5895
# Epoch 13/40
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0670 - accuracy: 0.6225 - val_loss: 1.1347 - val_accuracy: 0.5986
# Epoch 14/40
# 313/313 [==============================] - 6s 19ms/step - loss: 1.0425 - accuracy: 0.6306 - val_loss: 1.1319 - val_accuracy: 0.5989
# Epoch 15/40
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0228 - accuracy: 0.6371 - val_loss: 1.1291 - val_accuracy: 0.6034
# Epoch 16/40
# 313/313 [==============================] - 6s 19ms/step - loss: 0.9985 - accuracy: 0.6479 - val_loss: 1.1309 - val_accuracy: 0.6043
# Epoch 17/40
# 313/313 [==============================] - 6s 19ms/step - loss: 0.9851 - accuracy: 0.6518 - val_loss: 1.1143 - val_accuracy: 0.6066
# Epoch 18/40
# 313/313 [==============================] - 6s 19ms/step - loss: 0.9725 - accuracy: 0.6554 - val_loss: 1.1185 - val_accuracy: 0.6033
# Epoch 19/40
# 313/313 [==============================] - 6s 19ms/step - loss: 0.9467 - accuracy: 0.6661 - val_loss: 1.1123 - val_accuracy: 0.6066
# Epoch 20/40
# 313/313 [==============================] - 6s 18ms/step - loss: 0.9420 - accuracy: 0.6629 - val_loss: 1.1164 - val_accuracy: 0.6062
# Epoch 21/40
# 313/313 [==============================] - 6s 18ms/step - loss: 0.9214 - accuracy: 0.6714 - val_loss: 1.1100 - val_accuracy: 0.6055
# Epoch 22/40
# 313/313 [==============================] - 6s 19ms/step - loss: 0.9121 - accuracy: 0.6773 - val_loss: 1.1000 - val_accuracy: 0.6132
# Epoch 23/40
# 313/313 [==============================] - 6s 18ms/step - loss: 0.8931 - accuracy: 0.6826 - val_loss: 1.1018 - val_accuracy: 0.6129
# Epoch 24/40
# 313/313 [==============================] - 6s 18ms/step - loss: 0.8844 - accuracy: 0.6861 - val_loss: 1.1135 - val_accuracy: 0.6135
# Epoch 25/40
# 313/313 [==============================] - 6s 18ms/step - loss: 0.8670 - accuracy: 0.6885 - val_loss: 1.1026 - val_accuracy: 0.6097
# Epoch 26/40
# 313/313 [==============================] - 6s 18ms/step - loss: 0.8540 - accuracy: 0.6986 - val_loss: 1.1101 - val_accuracy: 0.6096
# Epoch 27/40
# 313/313 [==============================] - 6s 19ms/step - loss: 0.8494 - accuracy: 0.6967 - val_loss: 1.1244 - val_accuracy: 0.6105
# Epoch 28/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.8418 - accuracy: 0.7006 - val_loss: 1.1077 - val_accuracy: 0.6139
# Epoch 29/40
# 313/313 [==============================] - 6s 18ms/step - loss: 0.8320 - accuracy: 0.7014 - val_loss: 1.1146 - val_accuracy: 0.6095
# Epoch 30/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.8123 - accuracy: 0.7090 - val_loss: 1.1066 - val_accuracy: 0.6129
# Epoch 31/40
# 313/313 [==============================] - 6s 18ms/step - loss: 0.8095 - accuracy: 0.7104 - val_loss: 1.1136 - val_accuracy: 0.6173
# Epoch 32/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.7995 - accuracy: 0.7140 - val_loss: 1.1143 - val_accuracy: 0.6151
# Epoch 33/40
# 313/313 [==============================] - 6s 18ms/step - loss: 0.7875 - accuracy: 0.7181 - val_loss: 1.1128 - val_accuracy: 0.6168
# Epoch 34/40
# 313/313 [==============================] - 6s 18ms/step - loss: 0.7870 - accuracy: 0.7184 - val_loss: 1.1275 - val_accuracy: 0.6125
# Epoch 35/40
# 313/313 [==============================] - 6s 18ms/step - loss: 0.7769 - accuracy: 0.7220 - val_loss: 1.1163 - val_accuracy: 0.6109
# Epoch 36/40
# 313/313 [==============================] - 6s 18ms/step - loss: 0.7668 - accuracy: 0.7268 - val_loss: 1.1127 - val_accuracy: 0.6142
# Epoch 37/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.7542 - accuracy: 0.7299 - val_loss: 1.1177 - val_accuracy: 0.6173
# Epoch 38/40
# 313/313 [==============================] - 6s 19ms/step - loss: 0.7387 - accuracy: 0.7352 - val_loss: 1.1190 - val_accuracy: 0.6164
# Epoch 39/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.7307 - accuracy: 0.7375 - val_loss: 1.1061 - val_accuracy: 0.6213
# Epoch 40/40
# 313/313 [==============================] - 6s 19ms/step - loss: 0.7108 - accuracy: 0.7462 - val_loss: 1.1286 - val_accuracy: 0.6122
# 79/79 [==============================] - 1s 7ms/step - loss: 1.1313 - accuracy: 0.6173
#
# Test score/loss: 1.1313118934631348
# Test accuracy: 0.6172999739646912
# Epoch 1/40
# 313/313 [==============================] - 7s 19ms/step - loss: 2.3047 - accuracy: 0.0996 - val_loss: 2.3029 - val_accuracy: 0.0952
# Epoch 2/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3030 - accuracy: 0.0984 - val_loss: 2.3027 - val_accuracy: 0.0997
# Epoch 3/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3029 - accuracy: 0.0973 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 4/40
# 313/313 [==============================] - 7s 23ms/step - loss: 2.3028 - accuracy: 0.0988 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 5/40
# 313/313 [==============================] - 5s 15ms/step - loss: 2.3016 - accuracy: 0.0996 - val_loss: 2.2632 - val_accuracy: 0.1689
# Epoch 6/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.9848 - accuracy: 0.2654 - val_loss: 1.7756 - val_accuracy: 0.3394
# Epoch 7/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.6961 - accuracy: 0.3726 - val_loss: 1.5383 - val_accuracy: 0.4267
# Epoch 8/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.5611 - accuracy: 0.4201 - val_loss: 1.4879 - val_accuracy: 0.4445
# Epoch 9/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.4854 - accuracy: 0.4525 - val_loss: 1.3285 - val_accuracy: 0.5167
# Epoch 10/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.4140 - accuracy: 0.4834 - val_loss: 1.2770 - val_accuracy: 0.5371
# Epoch 11/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.3600 - accuracy: 0.5046 - val_loss: 1.2695 - val_accuracy: 0.5367
# Epoch 12/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.3215 - accuracy: 0.5193 - val_loss: 1.2575 - val_accuracy: 0.5332
# Epoch 13/40
# 313/313 [==============================] - 6s 18ms/step - loss: 1.2856 - accuracy: 0.5369 - val_loss: 1.1677 - val_accuracy: 0.5825
# Epoch 14/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.2567 - accuracy: 0.5485 - val_loss: 1.1671 - val_accuracy: 0.5878
# Epoch 15/40
# 313/313 [==============================] - 5s 15ms/step - loss: 1.2264 - accuracy: 0.5580 - val_loss: 1.1727 - val_accuracy: 0.5732
# Epoch 16/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.1926 - accuracy: 0.5702 - val_loss: 1.1635 - val_accuracy: 0.5873
# Epoch 17/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.1724 - accuracy: 0.5806 - val_loss: 1.0698 - val_accuracy: 0.6136
# Epoch 18/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.1559 - accuracy: 0.5891 - val_loss: 1.0504 - val_accuracy: 0.6240
# Epoch 19/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.1210 - accuracy: 0.6016 - val_loss: 1.0125 - val_accuracy: 0.6413
# Epoch 20/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.1038 - accuracy: 0.6077 - val_loss: 1.0275 - val_accuracy: 0.6362
# Epoch 21/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.0765 - accuracy: 0.6186 - val_loss: 1.0102 - val_accuracy: 0.6406
# Epoch 22/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.0546 - accuracy: 0.6256 - val_loss: 0.9977 - val_accuracy: 0.6478
# Epoch 23/40
# 313/313 [==============================] - 5s 18ms/step - loss: 1.0391 - accuracy: 0.6308 - val_loss: 1.0183 - val_accuracy: 0.6384
# Epoch 24/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.0185 - accuracy: 0.6375 - val_loss: 0.9264 - val_accuracy: 0.6729
# Epoch 25/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.0001 - accuracy: 0.6457 - val_loss: 0.9050 - val_accuracy: 0.6818
# Epoch 26/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.9846 - accuracy: 0.6483 - val_loss: 0.9073 - val_accuracy: 0.6782
# Epoch 27/40
# 313/313 [==============================] - 5s 16ms/step - loss: 0.9691 - accuracy: 0.6576 - val_loss: 0.8626 - val_accuracy: 0.6961
# Epoch 28/40
# 313/313 [==============================] - 5s 16ms/step - loss: 0.9468 - accuracy: 0.6653 - val_loss: 0.9521 - val_accuracy: 0.6636
# Epoch 29/40
# 313/313 [==============================] - 5s 16ms/step - loss: 0.9407 - accuracy: 0.6693 - val_loss: 0.8675 - val_accuracy: 0.6886
# Epoch 30/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.9294 - accuracy: 0.6694 - val_loss: 0.8623 - val_accuracy: 0.6962
# Epoch 31/40
# 313/313 [==============================] - 5s 16ms/step - loss: 0.9109 - accuracy: 0.6801 - val_loss: 0.8904 - val_accuracy: 0.6845
# Epoch 32/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.8986 - accuracy: 0.6855 - val_loss: 0.8301 - val_accuracy: 0.7063
# Epoch 33/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.8841 - accuracy: 0.6875 - val_loss: 0.8809 - val_accuracy: 0.6875
# Epoch 34/40
# 313/313 [==============================] - 6s 18ms/step - loss: 0.8733 - accuracy: 0.6903 - val_loss: 0.8508 - val_accuracy: 0.7030
# Epoch 35/40
# 313/313 [==============================] - 6s 18ms/step - loss: 0.8694 - accuracy: 0.6941 - val_loss: 0.8242 - val_accuracy: 0.7127
# Epoch 36/40
# 313/313 [==============================] - 5s 16ms/step - loss: 0.8542 - accuracy: 0.6991 - val_loss: 0.8165 - val_accuracy: 0.7145
# Epoch 37/40
# 313/313 [==============================] - 5s 16ms/step - loss: 0.8414 - accuracy: 0.7027 - val_loss: 0.7951 - val_accuracy: 0.7202
# Epoch 38/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.8323 - accuracy: 0.7055 - val_loss: 0.8129 - val_accuracy: 0.7144
# Epoch 39/40
# 313/313 [==============================] - 5s 16ms/step - loss: 0.8345 - accuracy: 0.7049 - val_loss: 0.7987 - val_accuracy: 0.7210
# Epoch 40/40
# 313/313 [==============================] - 5s 16ms/step - loss: 0.8258 - accuracy: 0.7084 - val_loss: 0.7790 - val_accuracy: 0.7326
# 79/79 [==============================] - 1s 7ms/step - loss: 0.8110 - accuracy: 0.7200
#
# Test score/loss: 0.8110026121139526
# Test accuracy: 0.7200000286102295

# %%
plt.figure(figsize=(12,6))
plt.plot(histories[2].history['accuracy'], label=f'Train')
plt.plot(histories[2].history['val_accuracy'], label=f'Val')
plt.legend(loc='best')
plt.show()

# %%
plt.figure(figsize=(12, 6))
for history, score, model_name, score_colour in zip(histories, scores, model_names, score_colours):
  plt.plot(history.history['accuracy'], label=f'Train - {model_name}')
  plt.axhline(y=score[1], color = score_colour, linestyle='--', label=f'Test - {model_name}')


plt.title('Model Accuracy Comparison')
plt.ylabel('Accuracy')
plt.xlabel('Epoch no.')
plt.legend(loc ='best')
plt.show()

# %% [markdown]
# **Analysis of the Deeper CNN results**
#
# This generates the test scores and plots for the new, deeper DNN.

# %%
#Testing
score = model.evaluate(input_X_test, output_Y_test, batch_size=BATCH_SIZE, verbose=VERBOSE)
print("\nTest score/loss:", score[0])
print('Test accuracy:', score[1])

# list all data in history
print(history.history.keys())

# summarize history for accuracy
#plt.plot(mo)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# 79/79 [==============================] - 0s 5ms/step - loss: 0.8110 - accuracy: 0.7200
#
# Test score/loss: 0.8110026121139526
# Test accuracy: 0.7200000286102295
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
