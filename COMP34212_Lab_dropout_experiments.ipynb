# %% [markdown]
# <a href="https://colab.research.google.com/github/TomShimo0/COMP34212-Lab/blob/main/COMP34212_Lab_dropout_experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Advanced Convolutional Neural Networks (CNNs) with CIFAR-10 dataset
# =========
#
# In this tutorial we will learn how to use more complex CNNs, showing that the training of a __deeper__ CNN can improve the performance of the model. We will also explore the concept of __data augmentation__ to understand how to increase the variability of the training set by, for example, rotating the original images to generate new training stimuli.
#
# This tutorail will use the CIFAR-10 training set.

# %% [markdown]
# **CNN for CIFAR-10**
#
# To work with more complex CNNs, we will now use a more complex training dataset called __CIFAR-10__. https://www.cs.toronto.edu/~kriz/cifar.html . CIFAR-10 is a benchamark machine learning set of low-resolution, colour images. It includes 60000 32x32 colour (using 3 RGB colour channels) images in these 10 classes of objects: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck. Each class has 6000. There are 50000 training images and 10000 test images. This dataset is enclosed in the default Anaconda KERAS package.

# %% [markdown]
# **Initialisation of the program**
#
# The program starts with the importing of typical Keras and other Python service modules.

# %%
# importing of modules for CIFAR-10 CNN
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import utils
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers.legacy import SGD, Adam, RMSprop

# importing of service libraries
import numpy as np
import matplotlib.pyplot as plt

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# The following constant and variable definitions are needed for the network and training parameters.

# %%
#training constants
BATCH_SIZE = 128
N_EPOCH = 40
N_CLASSES = 10
VERBOSE = 1
VALIDATION_SPLIT = 0.2
DROPOUT = 50
OPTIM = Adam()

print('Main variables initialised.')
# Out:
# Main variables initialised.

# %% [markdown]
# Constant definition for the training set images

# %%
# CIFAR_10 is a set of 60K images 32x32 pixels on 3 channels
IMG_CHANNELS = 3
IMG_ROWS = 32
IMG_COLS = 32

print('Image variables initialisation')
# Out:
# Image variables initialisation

# %% [markdown]
# __CIFAR-10 data loading and processing__
#
# Loading and preparation of the CIFAR-10 training set.

# %%
#load dataset
(input_X_train, output_y_train), (input_X_test, output_y_test) = cifar10.load_data()
print('input_X_train shape:', input_X_train.shape)
print(input_X_train.shape[0], 'train samples')
print(input_X_test.shape[0], 'test samples')

# convert to categorical
output_Y_train = utils.to_categorical(output_y_train, N_CLASSES)
output_Y_test = utils.to_categorical(output_y_test, N_CLASSES)

# float and normalization
input_X_train = input_X_train.astype('float32')
input_X_test = input_X_test.astype('float32')
input_X_train /= 255
input_X_test /= 255
# Out:
# input_X_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# Dropout Experiments
# -------------
#
# Each deep CNN layer will have the same dropout value, and the dense classificaiton layer will have 2x that dropout layer. The initial dropout will be 0.25, decremented by 0.05 each model

# %% [markdown]
# Make relevant lists to iterate through

# %%
# make a list of models
models = []
histories = []
scores = []
model_names = []

# %%
for i in range(DROPOUT, 25, -5):
  i = i/100

  # Complex DNN model definition (1 more layers)
  modelM = Sequential()

  modelM.add(Conv2D(32, kernel_size=(3, 3), padding='same', input_shape=(IMG_ROWS, IMG_COLS, IMG_CHANNELS)))
  modelM.add(Activation('relu'))
  modelM.add(Conv2D(32, kernel_size=(3, 3), padding='same'))
  modelM.add(Activation('relu'))
  modelM.add(MaxPooling2D(pool_size=(2, 2)))
  modelM.add(Dropout(i))

  modelM.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
  modelM.add(Activation('relu'))
  modelM.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
  modelM.add(Activation('relu'))
  modelM.add(MaxPooling2D(pool_size=(2, 2)))
  modelM.add(Dropout(i))

  modelM.add(Conv2D(128, kernel_size=(3, 3), padding='same'))
  modelM.add(Activation('relu'))
  modelM.add(Conv2D(128, kernel_size=(3, 3), padding='same'))
  modelM.add(Activation('relu'))
  modelM.add(MaxPooling2D(pool_size=(2, 2)))
  modelM.add(Dropout(i))

  modelM.add(Flatten())
  modelM.add(Dense(512))
  modelM.add(Activation('relu'))
  modelM.add(Dropout(0.5))
  modelM.add(Dense(N_CLASSES))
  modelM.add(Activation('softmax'))

  modelM.compile(loss='categorical_crossentropy', optimizer=OPTIM, metrics=['accuracy'])

  models.append(modelM)
  model_names.append(("dropout:", i))

  #model.summary()

# %% [markdown]
# Train

# %%
# training/fitting of the complex DNN models, recording data in lists
for model in models:
  history = model.fit(input_X_train, output_Y_train, batch_size=BATCH_SIZE, epochs=N_EPOCH, validation_split=VALIDATION_SPLIT,  verbose=VERBOSE)
  histories.append(history)

  # evaluation on test set
  score = model.evaluate(input_X_test, output_Y_test, batch_size=BATCH_SIZE, verbose=VERBOSE)
  scores.append(score)
  print("\nTest score/loss:", score[0])
  print('Test accuracy:', score[1])
# Out:
# Epoch 1/40
# 313/313 [==============================] - 7s 19ms/step - loss: 1.8775 - accuracy: 0.2912 - val_loss: 1.5747 - val_accuracy: 0.4217
# Epoch 2/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.4640 - accuracy: 0.4622 - val_loss: 1.2686 - val_accuracy: 0.5379
# Epoch 3/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.2911 - accuracy: 0.5303 - val_loss: 1.1340 - val_accuracy: 0.5951
# Epoch 4/40
# 313/313 [==============================] - 6s 18ms/step - loss: 1.1805 - accuracy: 0.5766 - val_loss: 1.0302 - val_accuracy: 0.6340
# Epoch 5/40
# 313/313 [==============================] - 6s 18ms/step - loss: 1.1015 - accuracy: 0.6067 - val_loss: 0.9405 - val_accuracy: 0.6602
# Epoch 6/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.0349 - accuracy: 0.6302 - val_loss: 0.9271 - val_accuracy: 0.6706
# Epoch 7/40
# 313/313 [==============================] - 5s 16ms/step - loss: 0.9763 - accuracy: 0.6549 - val_loss: 0.8756 - val_accuracy: 0.6823
# Epoch 8/40
# 313/313 [==============================] - 6s 18ms/step - loss: 0.9300 - accuracy: 0.6711 - val_loss: 0.8065 - val_accuracy: 0.7114
# Epoch 9/40
# 313/313 [==============================] - 5s 16ms/step - loss: 0.8927 - accuracy: 0.6852 - val_loss: 0.7591 - val_accuracy: 0.7370
# Epoch 10/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.8634 - accuracy: 0.6956 - val_loss: 0.7409 - val_accuracy: 0.7416
# Epoch 11/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.8362 - accuracy: 0.7062 - val_loss: 0.7440 - val_accuracy: 0.7360
# Epoch 12/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.8171 - accuracy: 0.7093 - val_loss: 0.6978 - val_accuracy: 0.7556
# Epoch 13/40
# 313/313 [==============================] - 5s 16ms/step - loss: 0.7931 - accuracy: 0.7209 - val_loss: 0.6889 - val_accuracy: 0.7606
# Epoch 14/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.7713 - accuracy: 0.7269 - val_loss: 0.7167 - val_accuracy: 0.7444
# Epoch 15/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.7681 - accuracy: 0.7273 - val_loss: 0.7646 - val_accuracy: 0.7331
# Epoch 16/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.7432 - accuracy: 0.7379 - val_loss: 0.6762 - val_accuracy: 0.7625
# Epoch 17/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.7355 - accuracy: 0.7415 - val_loss: 0.6857 - val_accuracy: 0.7591
# Epoch 18/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.7178 - accuracy: 0.7478 - val_loss: 0.6392 - val_accuracy: 0.7738
# Epoch 19/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.7102 - accuracy: 0.7487 - val_loss: 0.6506 - val_accuracy: 0.7782
# Epoch 20/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.7004 - accuracy: 0.7516 - val_loss: 0.6480 - val_accuracy: 0.7753
# Epoch 21/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.6923 - accuracy: 0.7576 - val_loss: 0.6172 - val_accuracy: 0.7857
# Epoch 22/40
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6806 - accuracy: 0.7597 - val_loss: 0.6264 - val_accuracy: 0.7822
# Epoch 23/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.6738 - accuracy: 0.7624 - val_loss: 0.5970 - val_accuracy: 0.7925
# Epoch 24/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.6745 - accuracy: 0.7624 - val_loss: 0.6495 - val_accuracy: 0.7825
# Epoch 25/40
# 313/313 [==============================] - 5s 16ms/step - loss: 0.6556 - accuracy: 0.7681 - val_loss: 0.6882 - val_accuracy: 0.7564
# Epoch 26/40
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6500 - accuracy: 0.7692 - val_loss: 0.6111 - val_accuracy: 0.7891
# Epoch 27/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.6444 - accuracy: 0.7739 - val_loss: 0.6227 - val_accuracy: 0.7873
# Epoch 28/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.6588 - accuracy: 0.7690 - val_loss: 0.6049 - val_accuracy: 0.7938
# Epoch 29/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.6407 - accuracy: 0.7728 - val_loss: 0.6314 - val_accuracy: 0.7826
# Epoch 30/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.6338 - accuracy: 0.7767 - val_loss: 0.6185 - val_accuracy: 0.7801
# Epoch 31/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.6296 - accuracy: 0.7771 - val_loss: 0.5735 - val_accuracy: 0.8036
# Epoch 32/40
# 313/313 [==============================] - 5s 16ms/step - loss: 0.6217 - accuracy: 0.7783 - val_loss: 0.6011 - val_accuracy: 0.7930
# Epoch 33/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.6117 - accuracy: 0.7838 - val_loss: 0.5721 - val_accuracy: 0.8023
# Epoch 34/40
# 313/313 [==============================] - 5s 16ms/step - loss: 0.6166 - accuracy: 0.7811 - val_loss: 0.5940 - val_accuracy: 0.7952
# Epoch 35/40
# 313/313 [==============================] - 5s 16ms/step - loss: 0.6135 - accuracy: 0.7853 - val_loss: 0.5917 - val_accuracy: 0.7968
# Epoch 36/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.6056 - accuracy: 0.7858 - val_loss: 0.6079 - val_accuracy: 0.7960
# Epoch 37/40
# 313/313 [==============================] - 5s 16ms/step - loss: 0.5987 - accuracy: 0.7904 - val_loss: 0.5900 - val_accuracy: 0.7997
# Epoch 38/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.5940 - accuracy: 0.7933 - val_loss: 0.5768 - val_accuracy: 0.8035
# Epoch 39/40
# 313/313 [==============================] - 5s 16ms/step - loss: 0.5954 - accuracy: 0.7918 - val_loss: 0.5773 - val_accuracy: 0.8052
# Epoch 40/40
# 313/313 [==============================] - 5s 17ms/step - loss: 0.5971 - accuracy: 0.7906 - val_loss: 0.5519 - val_accuracy: 0.8138
# 79/79 [==============================] - 0s 6ms/step - loss: 0.5806 - accuracy: 0.8022
#
# Test score/loss: 0.5805776119232178
# Test accuracy: 0.8022000193595886
# Epoch 1/40
# 313/313 [==============================] - 7s 19ms/step - loss: 2.1618 - accuracy: 0.1759 - val_loss: 1.9618 - val_accuracy: 0.2821
# Epoch 2/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.9190 - accuracy: 0.2926 - val_loss: 1.9905 - val_accuracy: 0.2786
# Epoch 3/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.8109 - accuracy: 0.3340 - val_loss: 1.7494 - val_accuracy: 0.3663
# Epoch 4/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.6889 - accuracy: 0.3770 - val_loss: 1.6318 - val_accuracy: 0.3974
# Epoch 5/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.6253 - accuracy: 0.4020 - val_loss: 1.6358 - val_accuracy: 0.3935
# Epoch 6/40
# 313/313 [==============================] - 6s 18ms/step - loss: 1.5849 - accuracy: 0.4172 - val_loss: 1.5378 - val_accuracy: 0.4298
# Epoch 7/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.5531 - accuracy: 0.4290 - val_loss: 1.5702 - val_accuracy: 0.4259
# Epoch 8/40
# 313/313 [==============================] - 5s 18ms/step - loss: 1.5287 - accuracy: 0.4414 - val_loss: 1.5715 - val_accuracy: 0.4214
# Epoch 9/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.5096 - accuracy: 0.4468 - val_loss: 1.5160 - val_accuracy: 0.4404
# Epoch 10/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.4958 - accuracy: 0.4484 - val_loss: 1.5377 - val_accuracy: 0.4278
# Epoch 11/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.4618 - accuracy: 0.4662 - val_loss: 1.6211 - val_accuracy: 0.3949
# Epoch 12/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.4437 - accuracy: 0.4697 - val_loss: 1.5150 - val_accuracy: 0.4331
# Epoch 13/40
# 313/313 [==============================] - 5s 18ms/step - loss: 1.4237 - accuracy: 0.4762 - val_loss: 1.4910 - val_accuracy: 0.4397
# Epoch 14/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.4009 - accuracy: 0.4883 - val_loss: 1.5108 - val_accuracy: 0.4465
# Epoch 15/40
# 313/313 [==============================] - 6s 18ms/step - loss: 1.3760 - accuracy: 0.4967 - val_loss: 1.4274 - val_accuracy: 0.4889
# Epoch 16/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.3580 - accuracy: 0.5027 - val_loss: 1.4506 - val_accuracy: 0.4595
# Epoch 17/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.3495 - accuracy: 0.5081 - val_loss: 1.4418 - val_accuracy: 0.4760
# Epoch 18/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.3262 - accuracy: 0.5158 - val_loss: 1.4859 - val_accuracy: 0.4524
# Epoch 19/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.3046 - accuracy: 0.5249 - val_loss: 1.4206 - val_accuracy: 0.4788
# Epoch 20/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.2934 - accuracy: 0.5304 - val_loss: 1.4096 - val_accuracy: 0.4916
# Epoch 21/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.2841 - accuracy: 0.5337 - val_loss: 1.4307 - val_accuracy: 0.4944
# Epoch 22/40
# 313/313 [==============================] - 5s 18ms/step - loss: 1.2623 - accuracy: 0.5404 - val_loss: 1.4610 - val_accuracy: 0.4962
# Epoch 23/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.2572 - accuracy: 0.5457 - val_loss: 1.4594 - val_accuracy: 0.4757
# Epoch 24/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.2392 - accuracy: 0.5487 - val_loss: 1.4123 - val_accuracy: 0.5000
# Epoch 25/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.2319 - accuracy: 0.5543 - val_loss: 1.3463 - val_accuracy: 0.5104
# Epoch 26/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.2173 - accuracy: 0.5595 - val_loss: 1.3909 - val_accuracy: 0.5165
# Epoch 27/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.2135 - accuracy: 0.5616 - val_loss: 1.5458 - val_accuracy: 0.4684
# Epoch 28/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.2004 - accuracy: 0.5673 - val_loss: 1.4141 - val_accuracy: 0.5010
# Epoch 29/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.1844 - accuracy: 0.5700 - val_loss: 1.4942 - val_accuracy: 0.4883
# Epoch 30/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.1756 - accuracy: 0.5777 - val_loss: 1.3809 - val_accuracy: 0.5173
# Epoch 31/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.1648 - accuracy: 0.5820 - val_loss: 1.2768 - val_accuracy: 0.5494
# Epoch 32/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.1569 - accuracy: 0.5871 - val_loss: 1.5148 - val_accuracy: 0.4952
# Epoch 33/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.1519 - accuracy: 0.5853 - val_loss: 1.3555 - val_accuracy: 0.5332
# Epoch 34/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.1417 - accuracy: 0.5918 - val_loss: 1.4986 - val_accuracy: 0.4936
# Epoch 35/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.1357 - accuracy: 0.5923 - val_loss: 1.3823 - val_accuracy: 0.5288
# Epoch 36/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.1281 - accuracy: 0.5969 - val_loss: 1.4960 - val_accuracy: 0.5095
# Epoch 37/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.1154 - accuracy: 0.5976 - val_loss: 1.3836 - val_accuracy: 0.5217
# Epoch 38/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.1144 - accuracy: 0.5971 - val_loss: 1.4652 - val_accuracy: 0.5023
# Epoch 39/40
# 313/313 [==============================] - 5s 16ms/step - loss: 1.1067 - accuracy: 0.6016 - val_loss: 1.4763 - val_accuracy: 0.4910
# Epoch 40/40
# 313/313 [==============================] - 5s 17ms/step - loss: 1.1061 - accuracy: 0.6037 - val_loss: 1.3448 - val_accuracy: 0.5311
# 79/79 [==============================] - 0s 5ms/step - loss: 1.3491 - accuracy: 0.5268
#
# Test score/loss: 1.349133849143982
# Test accuracy: 0.5267999768257141
# Epoch 1/40
# 313/313 [==============================] - 7s 18ms/step - loss: 2.3047 - accuracy: 0.0991 - val_loss: 2.3027 - val_accuracy: 0.1022
# Epoch 2/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3028 - accuracy: 0.0995 - val_loss: 2.3028 - val_accuracy: 0.0977
# Epoch 3/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0998 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 4/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.1005 - val_loss: 2.3029 - val_accuracy: 0.0952
# Epoch 5/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0988 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 6/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1000 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 7/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.1006 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 8/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0994 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 9/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0998 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 10/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0989 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 11/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.1006 - val_loss: 2.3027 - val_accuracy: 0.0977
# Epoch 12/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.1009 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 13/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1000 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 14/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0961 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 15/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0994 - val_loss: 2.3027 - val_accuracy: 0.0980
# Epoch 16/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1010 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 17/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.1001 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 18/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0997 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 19/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1006 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 20/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1007 - val_loss: 2.3027 - val_accuracy: 0.0977
# Epoch 21/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0996 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 22/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1002 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 23/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1001 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 24/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1001 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 25/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.1012 - val_loss: 2.3027 - val_accuracy: 0.0980
# Epoch 26/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0988 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 27/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0970 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 28/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0982 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 29/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0986 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 30/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0993 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 31/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0997 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 32/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1013 - val_loss: 2.3027 - val_accuracy: 0.0980
# Epoch 33/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1009 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 34/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0974 - val_loss: 2.3028 - val_accuracy: 0.0980
# Epoch 35/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0981 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 36/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0991 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 37/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0989 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 38/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1013 - val_loss: 2.3027 - val_accuracy: 0.0977
# Epoch 39/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0993 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 40/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0976 - val_loss: 2.3027 - val_accuracy: 0.0952
# 79/79 [==============================] - 1s 7ms/step - loss: 2.3026 - accuracy: 0.1000
#
# Test score/loss: 2.3026037216186523
# Test accuracy: 0.10000000149011612
# Epoch 1/40
# 313/313 [==============================] - 7s 18ms/step - loss: 2.3069 - accuracy: 0.0971 - val_loss: 2.3028 - val_accuracy: 0.0980
# Epoch 2/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3029 - accuracy: 0.0993 - val_loss: 2.3027 - val_accuracy: 0.1014
# Epoch 3/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3028 - accuracy: 0.0985 - val_loss: 2.3026 - val_accuracy: 0.1014
# Epoch 4/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3028 - accuracy: 0.0965 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 5/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0981 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 6/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0997 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 7/40
# 313/313 [==============================] - 6s 18ms/step - loss: 2.3027 - accuracy: 0.0968 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 8/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0975 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 9/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0979 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 10/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0995 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 11/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0989 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 12/40
# 313/313 [==============================] - 6s 18ms/step - loss: 2.3027 - accuracy: 0.0991 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 13/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0988 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 14/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0987 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 15/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0983 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 16/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0997 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 17/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0972 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 18/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1012 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 19/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0984 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 20/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.1001 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 21/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0975 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 22/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1010 - val_loss: 2.3027 - val_accuracy: 0.0977
# Epoch 23/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.1002 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 24/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0998 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 25/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1001 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 26/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0995 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 27/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.1017 - val_loss: 2.3027 - val_accuracy: 0.0977
# Epoch 28/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0985 - val_loss: 2.3027 - val_accuracy: 0.0977
# Epoch 29/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0992 - val_loss: 2.3027 - val_accuracy: 0.0977
# Epoch 30/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0996 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 31/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1012 - val_loss: 2.3027 - val_accuracy: 0.0980
# Epoch 32/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0980 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 33/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0983 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 34/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.1002 - val_loss: 2.3027 - val_accuracy: 0.0997
# Epoch 35/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0986 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 36/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0998 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 37/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.1009 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 38/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0999 - val_loss: 2.3027 - val_accuracy: 0.0977
# Epoch 39/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0981 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 40/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0986 - val_loss: 2.3027 - val_accuracy: 0.0952
# 79/79 [==============================] - 0s 6ms/step - loss: 2.3026 - accuracy: 0.1000
#
# Test score/loss: 2.302597761154175
# Test accuracy: 0.10000000149011612
# Epoch 1/40
# 313/313 [==============================] - 7s 19ms/step - loss: 2.3039 - accuracy: 0.1018 - val_loss: 2.3028 - val_accuracy: 0.1022
# Epoch 2/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3028 - accuracy: 0.0997 - val_loss: 2.3030 - val_accuracy: 0.1025
# Epoch 3/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3028 - accuracy: 0.0992 - val_loss: 2.3027 - val_accuracy: 0.0997
# Epoch 4/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3028 - accuracy: 0.0993 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 5/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3028 - accuracy: 0.1004 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 6/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3028 - accuracy: 0.0979 - val_loss: 2.3027 - val_accuracy: 0.0997
# Epoch 7/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3028 - accuracy: 0.0990 - val_loss: 2.3027 - val_accuracy: 0.0977
# Epoch 8/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0988 - val_loss: 2.3026 - val_accuracy: 0.1003
# Epoch 9/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1000 - val_loss: 2.3026 - val_accuracy: 0.1014
# Epoch 10/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0980 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 11/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0968 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 12/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0984 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 13/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0981 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 14/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0970 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 15/40
# 313/313 [==============================] - 5s 18ms/step - loss: 2.3027 - accuracy: 0.0999 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 16/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0994 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 17/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1012 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 18/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0979 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 19/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1008 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 20/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0995 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 21/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0994 - val_loss: 2.3027 - val_accuracy: 0.0980
# Epoch 22/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0982 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 23/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0988 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 24/40
# 313/313 [==============================] - 6s 18ms/step - loss: 2.3027 - accuracy: 0.0979 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 25/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0985 - val_loss: 2.3027 - val_accuracy: 0.0997
# Epoch 26/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1003 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 27/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0993 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 28/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0989 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 29/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1005 - val_loss: 2.3027 - val_accuracy: 0.0977
# Epoch 30/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0996 - val_loss: 2.3027 - val_accuracy: 0.0980
# Epoch 31/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0976 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 32/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0985 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 33/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.1003 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 34/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0978 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 35/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.0983 - val_loss: 2.3028 - val_accuracy: 0.0952
# Epoch 36/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0998 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 37/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.1000 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 38/40
# 313/313 [==============================] - 5s 17ms/step - loss: 2.3027 - accuracy: 0.1012 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 39/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0995 - val_loss: 2.3027 - val_accuracy: 0.0952
# Epoch 40/40
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3027 - accuracy: 0.0979 - val_loss: 2.3027 - val_accuracy: 0.0952
# 79/79 [==============================] - 0s 6ms/step - loss: 2.3026 - accuracy: 0.1000
#
# Test score/loss: 2.302603006362915
# Test accuracy: 0.10000000149011612

# %%
plt.figure(figsize=(12, 6))
for history, model_name, in zip(histories, model_names):
  plt.plot(history.history['accuracy'], label=f'Train - {model_name}')


plt.title('Model Accuracy Comparison')
plt.ylabel('Accuracy')
plt.xlabel('Epoch no.')
plt.legend(loc ='best')
plt.show()

# %%
plt.figure(figsize=(12, 6))

plt.plot(histories[0].history['accuracy'], label=f'Train - {model_names[0]}')
plt.plot(histories[0].history['val_accuracy'], label=f'Val - {model_names[0]}')
plt.axhline(y=scores[0][1], linestyle='--', label=f'Test - {model_names[0]}')


plt.title('Model Accuracy Comparison')
plt.ylabel('Accuracy')
plt.xlabel('Epoch no.')
plt.legend(loc ='best')
plt.show()
